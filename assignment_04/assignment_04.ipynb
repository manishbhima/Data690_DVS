# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\bhima\Downloads\CollegeScorecard_Raw_Data\CollegeScorecard_Raw_Data\MERGED2017_18_PP.csv')
# Out:
# C:\Users\bhima\AppData\Local\Temp\ipykernel_22600\1703677530.py:1: DtypeWarning: Columns (1729) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r'C:\Users\bhima\Downloads\CollegeScorecard_Raw_Data\CollegeScorecard_Raw_Data\MERGED2017_18_PP.csv')

# %%
df.head(2)
# Out:
#    UNITID   OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654  100200    1002             Alabama A & M University      Normal
# 1  100663  105200    1052  University of Alabama at Birmingham  Birmingham
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# 1                           NaN       0.4009        0.5488  13308.0  9888.0
#
#    SCUGFFN  POOLYRS_FTFTAIDPCT  FTFTPCTPELL_POOLED_SUPP  \
# 0   1410.0                 NaN                      NaN
# 1   1948.0                 NaN                      NaN
#
#    FTFTPCTFLOAN_POOLED_SUPP  SCUGFFN_POOLED
# 0                       NaN             NaN
# 1                       NaN             NaN
#
# ...

# %%
df.shape
# Out:
# (7112, 1986)

# %%
df.shape[0]
# Out:
# 7112

# %%
df.shape[1]
# Out:
# 1986

# %% [markdown]
# #  List of First 5 colleges

# %%
df['INSTNM'][:5]
# Out:
# 0               Alabama A & M University
# 1    University of Alabama at Birmingham
# 2                     Amridge University
# 3    University of Alabama in Huntsville
# 4               Alabama State University
# Name: INSTNM, dtype: object

# %% [markdown]
# #  List of Last 5 colleges

# %%
df['INSTNM'][-5:]
# Out:
# 7107                     Arizona State University at Yuma
# 7108    Bay Area Medical Academy - San Jose Satellite ...
# 7109             High Desert Medical College - Bakerfield
# 7110                                         BCI - Malden
# 7111                 HCI College - Fort Lauderdale Campus
# Name: INSTNM, dtype: object

# %%
df.tail()
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# # List of Random 5 Colleges

# %%
df.sample(5)
# Out:
#       UNITID    OPEID  OPEID6  \
# 5923  469124  3030603   30306
# 1390  159993   202000    2020
# 6454  487153  2155308   21553
# 2765  204866   310002    3100
# 4827  438708  4119000   41190
#
#                                                  INSTNM         CITY STABBR  \
# 5923                        Cortiva Institute-Las Vegas    Las Vegas     NV
# 1390                  University of Louisiana at Monroe       Monroe     LA
# 6454  The Chicago School of Professional Psychology ...  New Orleans     LA
# 2765                  Ohio University-Zanesville Campus   Zanesville     OH
# 4827  Eastern West Virginia Community and Technical ...   Moorefield     WV
#
#              ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 5923  89123-2069           NaN      NaN     NaN  ...
# 1390  71209-0000           NaN      NaN     NaN  ...
# 6454  70125-1056           NaN      NaN     NaN  ...
# 2765       43701           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# ### Creating a smaller data frame with the following 9 variables:
# * UNITID - University ID
# * INSTNM - Institution Name
# * CITY  - City Name
# * STABBR - State Postcode
# * ZIP - ZIP Code
# * ADM_RATE - Admission Rate
# * UGDS - Enrollment of undergraduate certificate/degree-seeking students
# * TUITIONFEE_IN - In State Tuition fees
# * MN_EARN_WNE_P10 -
# Mean earnings of students working and not enrolled 10 years after entry

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Columns: 1986 entries, UNITID to SCUGFFN_POOLED
# dtypes: float64(1931), int64(12), object(43)
# memory usage: 107.8+ MB

# %%
df.describe()
# Out:
#              UNITID         OPEID        OPEID6  ACCREDAGENCY  INSTURL  \
# count  7.112000e+03  7.112000e+03   7112.000000           0.0      0.0
# mean   1.867121e+06  1.866750e+06  16755.217660           NaN      NaN
# std    6.958737e+06  3.315240e+06  14589.294487           NaN      NaN
# min    1.006540e+05  1.002000e+05   1002.000000           NaN      NaN
# 25%    1.740728e+05  3.229750e+05   3224.750000           NaN      NaN
# 50%    2.289995e+05  1.056050e+06  10542.000000           NaN      NaN
# 75%    4.506005e+05  3.025825e+06  30106.000000           NaN      NaN
# max    4.900540e+07  8.209884e+07  42698.000000           NaN      NaN
#
#        NPCURL  SCH_DEG  HCM2         MAIN    NUMBRANCH  ...  \
# count     0.0      0.0   0.0  7112.000000  7112.000000  ...
# mean      NaN      NaN   NaN     0.767717     3.883155  ...
# std       NaN      NaN   NaN     0.422319     9.088975  ...
# min       NaN      NaN   NaN     0.000000     1.000000  ...
# ...

# %%
df.columns
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'ZIP',
#        'ACCREDAGENCY', 'INSTURL', 'NPCURL',
#        ...
#        'OMENRUP_PARTTIME_POOLED_SUPP', 'FTFTPCTPELL', 'FTFTPCTFLOAN', 'UG12MN',
#        'G12MN', 'SCUGFFN', 'POOLYRS_FTFTAIDPCT', 'FTFTPCTPELL_POOLED_SUPP',
#        'FTFTPCTFLOAN_POOLED_SUPP', 'SCUGFFN_POOLED'],
#       dtype='object', length=1986)

# %%
df1=df[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]

# %%
df1.shape
# Out:
# (7112, 9)

# %%
df1.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0    0.9027   4824.0         9857.0              NaN
# 1    0.9181  12866.0         8328.0              NaN
# 2       NaN    318.0         6900.0              NaN
# 3    0.8123   6917.0        10280.0              NaN
# 4    0.9787   4189.0        11068.0              NaN

# %% [markdown]
# ## List Of First 10 Colleges

# %%
df1.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# ## List of Last 10 Colleges

# %%
df1.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# ## List of Random 10 Colleges

# %%
df1.sample(10)
# Out:
#         UNITID                                             INSTNM  \
# 4712    431691                            Northland Career Center
# 1698    171155                               Mid Michigan College
# 4210    372240      Universal College of Beauty Inc-Los Angeles 2
# 6980  36520406                              Vista College-Killeen
# 6797  16061202  Southeastern Louisiana University - St Amant H...
# 359     117733                         Los Angeles Valley College
# 5856    461698                               Real Barbers College
# 4245    375656                   Chisholm Trail Technology Center
# 4584    419031                            United Technical Center
# 3610    230889                                    Goddard College
#
#              CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 4712  Platte City     MO       64079       NaN      2.0            NaN
# 1698     Harrison     MI  48625-9447       NaN   2913.0         4597.0
# ...

# %% [markdown]
# ## Displaying UMBC

# %%
df1[df1['STABBR']=="MD"]
# Out:
#         UNITID                                  INSTNM          CITY STABBR  \
# 1446    161651     Aesthetics Institute of Cosmetology  Gaithersburg     MD
# 1447    161688            Allegany College of Maryland    Cumberland     MD
# 1448    161767          Anne Arundel Community College        Arnold     MD
# 1449    161776               Brightwood College-Towson        Towson     MD
# 1450    161800                     Award Beauty School    Hagerstown     MD
# ...        ...                                     ...           ...    ...
# 6800  16210401          Cecil College - Elkton Station        Elkton     MD
# 7004  43018401     Strayer University-Rockville Campus     Rockville     MD
# 7005  43018402  Strayer University-Anne Arundel Campus  Millersville     MD
# 7006  43018403   Strayer University-White Marsh Campus     Baltimore     MD
# 7007  43018404  Strayer University-Owings Mills Campus  Owings Mills     MD
#
# ...

# %%
df1[df1['CITY']=="Baltimore"]
# Out:
#         UNITID                                   INSTNM       CITY STABBR  \
# 1451    161855          Baltimore Studio of Hair Design  Baltimore     MD
# 1452    161864         Baltimore City Community College  Baltimore     MD
# 1453    161873                  University of Baltimore  Baltimore     MD
# 1460    162283                  Coppin State University  Baltimore     MD
# 1462    162371             North American Trade Schools  Baltimore     MD
# 1466    162654                          Goucher College  Baltimore     MD
# 1473    162928                 Johns Hopkins University  Baltimore     MD
# 1475    163046               Loyola University Maryland  Baltimore     MD
# 1477    163259         University of Maryland Baltimore  Baltimore     MD
# 1478    163268  University of Maryland-Baltimore County  Baltimore     MD
# 1480    163295        Maryland Institute College of Art  Baltimore     MD
# 1485    163453                  Morgan State University  Baltimore     MD
# ...

# %%
df1[df1['INSTNM']=="University of Maryland-Baltimore County"]
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %% [markdown]
# ## Displaying University of Maryland College Park

# %%
df1[df1['CITY']=="College Park"]
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %%
df1[df1['INSTNM']=="University of Maryland-College Park"]
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %% [markdown]
# ## Displaying Loyola College-Maryland

# %%
df1[df1['INSTNM']=="Loyola College-Maryland"]
# Out:
# Empty DataFrame
# Columns: [UNITID, INSTNM, CITY, STABBR, ZIP, ADM_RATE, UGDS, TUITIONFEE_IN, MN_EARN_WNE_P10]
# Index: []

# %%
df.loc[df['INSTNM'].str.startswith('Loyola')]
# Out:
#       UNITID    OPEID  OPEID6                         INSTNM         CITY  \
# 366   117946  1164900   11649    Loyola Marymount University  Los Angeles
# 1000  146719   171000    1710      Loyola University Chicago      Chicago
# 1385  159656   201600    2016  Loyola University New Orleans  New Orleans
# 1475  163046   207800    2078     Loyola University Maryland    Baltimore
#
#      STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 366      CA  90045-2659           NaN      NaN     NaN  ...
# 1000     IL       60660           NaN      NaN     NaN  ...
# 1385     LA  70118-6143           NaN      NaN     NaN  ...
# 1475     MD  21210-2699           NaN      NaN     NaN  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN  \
# 366                            NaN       0.1235        0.3637   6591.0
# 1000                           NaN       0.2587        0.6127  12864.0
# 1385                           NaN       0.3252        0.6618   2766.0
# ...

# %%
df1[df1['INSTNM']=="Loyola University Maryland"]
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %% [markdown]
# ## Displaying Johns Hopkins University

# %%
df1[df1['INSTNM']=="Johns Hopkins University"]
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %%
# data=df1[(df1['INSTNM']=="Johns Hopkins University") &
#          (df1['INSTNM']=="University of Maryland-Baltimore County") & 
#          (df1['INSTNM']=="University of Maryland-College Park") &
#          (df1['INSTNM']=="Loyola University Maryland")]

# %% [markdown]
#  ## Displaying min, max, and average in-state tution of the above four institutions.

# %%
data = df1[(df['INSTNM']=="Johns Hopkins University") | (df['INSTNM']=="Loyola University Maryland") | (df['INSTNM']=="University of Maryland-Baltimore County") | (df['INSTNM']=="University of Maryland-College Park") ]

# %%
data
# Out:
#       UNITID                                   INSTNM          CITY STABBR  \
# 1473  162928                 Johns Hopkins University     Baltimore     MD
# 1475  163046               Loyola University Maryland     Baltimore     MD
# 1478  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1479  163286      University of Maryland-College Park  College Park     MD
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473  21218-2688    0.1254   5663.0        52170.0              NaN
# 1475  21210-2699    0.7528   3903.0        47560.0              NaN
# 1478       21250    0.6021  11130.0        11518.0              NaN
# 1479       20742    0.4450  29273.0        10399.0              NaN

# %%
data['TUITIONFEE_IN'].max()
# Out:
# 52170.0

# %%
data['TUITIONFEE_IN'].min()
# Out:
# 10399.0

# %%
data['TUITIONFEE_IN'].mean()
# Out:
# 30411.75

# %% [markdown]
# ## Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis

# %%
fivestates=df1[(df1['STABBR']=="MD") | (df1['STABBR']=="VA") | (df1['STABBR']=="DC") | (df1['STABBR']=="PA") | (df1['STABBR']=="DE")]

# %%
fivestates
# Out:
#         UNITID                                             INSTNM  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...
# 635     130873                          Dawn Career Institute LLC
# 636     130907         Delaware Technical Community College-Terry
# 637     130934                          Delaware State University
# 638     130943                             University of Delaware
# ...        ...                                                ...
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7084  47503303      Relay Graduate School of Education - Delaware
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7094  47503313  Relay Graduate School of Education - Washingto...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#               CITY STABBR        ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 634          Lewes     DE      19958       NaN     59.0            NaN
# ...

# %%
fivestates.STABBR.unique()
# Out:
# array(['DE', 'DC', 'MD', 'PA', 'VA'], dtype=object)

# %%
fivestates.to_csv(r'C:\Users\bhima\OneDrive\Documents\five_states\five_states.csv')
