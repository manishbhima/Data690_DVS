# %% [markdown]
# <a href="https://colab.research.google.com/github/manishbhima/Data690_DVS/blob/main/world_development_explorer/Individual__project_part_B_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NAME- MANISH BHIMA
#
# # Factors that influence the economy and growth of a country
#
# ## INDICATORS:
# - Exports of goods and services (% of GDP)
#
# - Trade (% of GDP)
#
# - Industry (including construction), value added (% of GDP)
#
# - GDP per capita, PPP (current international $)
#
# ## Countries compared:
# - India
#
# - United states
#
# - Italy
#
# - China
# ## Introduction:
# - Economic growth is defined as a rise or improvement in the market value of an economy's commodities and services through time. This expansion is likewise proportional to the percent rate of rise in real Gross Domestic Product (GDP).

# %%
import pandas as pd
import plotly.express as px

# %%
import plotly

print(plotly.__version__)
# Out:
# 5.11.0

# %%
# !pip install plotly  --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Collecting plotly
#   Downloading plotly-5.11.0-py2.py3-none-any.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 8.3 MB/s
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.1.0)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-5.11.0

# %%
df = pd.read_csv("https://raw.githubusercontent.com/manishbhima/Data690_DVS/main/world_development_explorer/wdx_long%20(1).csv")
df
# Out:
#     Unnamed: 0  Year         value          indicator Country Code  \
# 0            0  2016     19.584380     NE.EXP.GNFS.ZS          CHN
# 1            1  2017     19.692277     NE.EXP.GNFS.ZS          CHN
# 2            2  2018     19.112104     NE.EXP.GNFS.ZS          CHN
# 3            3  2019     18.409992     NE.EXP.GNFS.ZS          CHN
# 4            4  2020     18.541060     NE.EXP.GNFS.ZS          CHN
# ..         ...   ...           ...                ...          ...
# 88          88  2017  59914.777797  NY.GDP.PCAP.PP.CD          USA
# 89          89  2018  62805.253758  NY.GDP.PCAP.PP.CD          USA
# 90          90  2019  65094.799429  NY.GDP.PCAP.PP.CD          USA
# 91          91  2020  63027.679527  NY.GDP.PCAP.PP.CD          USA
# 92          92  2021  69287.536588  NY.GDP.PCAP.PP.CD          USA
#
#      Country Name               Region         Income Group    Lending Type
# 0           China  East Asia & Pacific  Upper middle income            IBRD
# 1           China  East Asia & Pacific  Upper middle income            IBRD
# 2           China  East Asia & Pacific  Upper middle income            IBRD
# 3           China  East Asia & Pacific  Upper middle income            IBRD
# 4           China  East Asia & Pacific  Upper middle income            IBRD
# ..            ...                  ...                  ...             ...
# 88  United States        North America          High income  Not classified
# 89  United States        North America          High income  Not classified
# 90  United States        North America          High income  Not classified
# 91  United States        North America          High income  Not classified
# 92  United States        North America          High income  Not classified
#
# [93 rows x 9 columns]

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#     Year         value          indicator Country Code   Country Name  \
# 0   2016     19.584380     NE.EXP.GNFS.ZS          CHN          China
# 1   2017     19.692277     NE.EXP.GNFS.ZS          CHN          China
# 2   2018     19.112104     NE.EXP.GNFS.ZS          CHN          China
# 3   2019     18.409992     NE.EXP.GNFS.ZS          CHN          China
# 4   2020     18.541060     NE.EXP.GNFS.ZS          CHN          China
# ..   ...           ...                ...          ...            ...
# 88  2017  59914.777797  NY.GDP.PCAP.PP.CD          USA  United States
# 89  2018  62805.253758  NY.GDP.PCAP.PP.CD          USA  United States
# 90  2019  65094.799429  NY.GDP.PCAP.PP.CD          USA  United States
# 91  2020  63027.679527  NY.GDP.PCAP.PP.CD          USA  United States
# 92  2021  69287.536588  NY.GDP.PCAP.PP.CD          USA  United States
#
#                  Region         Income Group    Lending Type
# 0   East Asia & Pacific  Upper middle income            IBRD
# 1   East Asia & Pacific  Upper middle income            IBRD
# 2   East Asia & Pacific  Upper middle income            IBRD
# 3   East Asia & Pacific  Upper middle income            IBRD
# 4   East Asia & Pacific  Upper middle income            IBRD
# ..                  ...                  ...             ...
# 88        North America          High income  Not classified
# 89        North America          High income  Not classified
# 90        North America          High income  Not classified
# 91        North America          High income  Not classified
# 92        North America          High income  Not classified
#
# [93 rows x 8 columns]

# %%
df_2016 = df.query("Year == 2016")
df_2016.sample(10)
# Out:
#     Year         value          indicator Country Code   Country Name  \
# 41  2016     18.042221     NV.IND.TOTL.ZS          USA  United States
# 52  2016     40.082486     NE.TRD.GNFS.ZS          IND          India
# 18  2016     11.939539     NE.EXP.GNFS.ZS          USA  United States
# 12  2016     29.327891     NE.EXP.GNFS.ZS          ITA          Italy
# 58  2016     55.367603     NE.TRD.GNFS.ZS          ITA          Italy
# 81  2016  39926.954663  NY.GDP.PCAP.PP.CD          ITA          Italy
# 69  2016  13483.377267  NY.GDP.PCAP.PP.CD          CHN          China
# 6   2016     19.158235     NE.EXP.GNFS.ZS          IND          India
# 46  2016     36.894415     NE.TRD.GNFS.ZS          CHN          China
# 0   2016     19.584380     NE.EXP.GNFS.ZS          CHN          China
#
#                    Region         Income Group    Lending Type
# 41          North America          High income  Not classified
# 52             South Asia  Lower middle income            IBRD
# 18          North America          High income  Not classified
# 12  Europe & Central Asia          High income  Not classified
# 58  Europe & Central Asia          High income  Not classified
# 81  Europe & Central Asia          High income  Not classified
# 69    East Asia & Pacific  Upper middle income            IBRD
# 6              South Asia  Lower middle income            IBRD
# 46    East Asia & Pacific  Upper middle income            IBRD
# 0     East Asia & Pacific  Upper middle income            IBRD

# %%
df_2016 = df_2016.query("indicator in['NE.EXP.GNFS.ZS','NE.TRD.GNFS.ZS','NV.IND.TOTL.ZS','NY.GDP.PCAP.PP.CD']")
df_2016.head()
# Out:
#     Year      value       indicator Country Code   Country Name  \
# 0   2016  19.584380  NE.EXP.GNFS.ZS          CHN          China
# 6   2016  19.158235  NE.EXP.GNFS.ZS          IND          India
# 12  2016  29.327891  NE.EXP.GNFS.ZS          ITA          Italy
# 18  2016  11.939539  NE.EXP.GNFS.ZS          USA  United States
# 23  2016  39.580622  NV.IND.TOTL.ZS          CHN          China
#
#                    Region         Income Group    Lending Type
# 0     East Asia & Pacific  Upper middle income            IBRD
# 6              South Asia  Lower middle income            IBRD
# 12  Europe & Central Asia          High income  Not classified
# 18          North America          High income  Not classified
# 23    East Asia & Pacific  Upper middle income            IBRD

# %%
df_pivot = df_2016.pivot(index =['Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot.head()
# Out:
# indicator Country Code   Country Name                 Region  \
# 0                  CHN          China    East Asia & Pacific
# 1                  IND          India             South Asia
# 2                  ITA          Italy  Europe & Central Asia
# 3                  USA  United States          North America
#
# indicator         Income Group    Lending Type  NE.EXP.GNFS.ZS  \
# 0          Upper middle income            IBRD       19.584380
# 1          Lower middle income            IBRD       19.158235
# 2                  High income  Not classified       29.327891
# 3                  High income  Not classified       11.939539
#
# indicator  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               36.894415       39.580622       13483.377267
# 1               40.082486       26.619000        5839.864817
# 2               55.367603       21.217944       39926.954663
# 3               26.586999       18.042221       57866.744934

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country Code       4 non-null      object
#  1   Country Name       4 non-null      object
#  2   Region             4 non-null      object
#  3   Income Group       4 non-null      object
#  4   Lending Type       4 non-null      object
#  5   NE.EXP.GNFS.ZS     4 non-null      float64
#  6   NE.TRD.GNFS.ZS     4 non-null      float64
#  7   NV.IND.TOTL.ZS     4 non-null      float64
#  8   NY.GDP.PCAP.PP.CD  4 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 416.0+ bytes

# %%
fig = px.bar(
    df_pivot,
    x="Country Name",
    y="NE.EXP.GNFS.ZS",
    title="TOP 5 Countries by 2016 Exports of goods and services (% of GDP)",
    color='Country Name',
    labels={"NE.EXP.GNFS.ZS":"2016 Exports of goods and services (% of GDP)"}
).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.16.1.min.js"></script>                <div id="86e3bb04-d189-4552-b5b1-8c505cfc846a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86e3bb04-d189-4552-b5b1-8c505cfc846a")) {                    Plotly.newPlot(                        "86e3bb04-d189-4552-b5b1-8c505cfc846a",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[19.5843800536],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[19.1582349106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[29.3278907466],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[11.9395387322],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0 ...

# %% [markdown]
# #  Economic growth due to Indsutries:
# -  Export sales growth generates revenue and earnings for firms, allowing them to boost capital expenditure. Higher investment boosts a country's production capacity, which in turn boosts its export potential.
# - In the year 2016, the percentage of exports of goods and services contributing to GDP by various countries is depicted in the bar graph above.
# - The Italy exports of goods and services contribute 36.7 percent to its GDP, making it the country with the highest proportion of GDP contributed by exports.
# - China with 24.5 of the market, followed by India with 23.9 % and United States with 14.9%..

# %%
df2 = df.query("indicator in['NE.EXP.GNFS.ZS','NE.TRD.GNFS.ZS','NV.IND.TOTL.ZS','NY.GDP.PCAP.PP.CD']")
df2.sample(10)
# Out:
#     Year      value       indicator Country Code   Country Name  \
# 4   2020  18.541060  NE.EXP.GNFS.ZS          CHN          China
# 47  2017  37.632413  NE.TRD.GNFS.ZS          CHN          China
# 35  2016  21.217944  NV.IND.TOTL.ZS          ITA          Italy
# 5   2021  20.009814  NE.EXP.GNFS.ZS          CHN          China
# 7   2017  18.791765  NE.EXP.GNFS.ZS          IND          India
# 20  2018  12.342241  NE.EXP.GNFS.ZS          USA  United States
# 29  2016  26.619000  NV.IND.TOTL.ZS          IND          India
# 68  2020  23.442457  NE.TRD.GNFS.ZS          USA  United States
# 23  2016  39.580622  NV.IND.TOTL.ZS          CHN          China
# 36  2017  21.300405  NV.IND.TOTL.ZS          ITA          Italy
#
#                    Region         Income Group    Lending Type
# 4     East Asia & Pacific  Upper middle income            IBRD
# 47    East Asia & Pacific  Upper middle income            IBRD
# 35  Europe & Central Asia          High income  Not classified
# 5     East Asia & Pacific  Upper middle income            IBRD
# 7              South Asia  Lower middle income            IBRD
# 20          North America          High income  Not classified
# 29             South Asia  Lower middle income            IBRD
# 68          North America          High income  Not classified
# 23    East Asia & Pacific  Upper middle income            IBRD
# 36  Europe & Central Asia          High income  Not classified

# %%
df_pivot2 = df2.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot2.head()


year_2016=df_pivot2[df_pivot2["Year"]==2016]
# Out:
# indicator  Year Country Code   Country Name                 Region  \
# 0          2016          CHN          China    East Asia & Pacific
# 1          2016          IND          India             South Asia
# 2          2016          ITA          Italy  Europe & Central Asia
# 3          2016          USA  United States          North America
# 4          2017          CHN          China    East Asia & Pacific
#
# indicator         Income Group    Lending Type  NE.EXP.GNFS.ZS  \
# 0          Upper middle income            IBRD       19.584380
# 1          Lower middle income            IBRD       19.158235
# 2                  High income  Not classified       29.327891
# 3                  High income  Not classified       11.939539
# 4          Upper middle income            IBRD       19.692277
#
# indicator  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               36.894415       39.580622       13483.377267
# 1               40.082486       26.619000        5839.864817
# 2               55.367603       21.217944       39926.954663
# 3               26.586999       18.042221       57866.744934
# 4               37.632413       39.851698       14243.532611

# %%
year_2016=df_pivot2[df_pivot2["Year"]==2016]

# %%
year_2016
# Out:
# indicator  Year Country Code   Country Name                 Region  \
# 0          2016          CHN          China    East Asia & Pacific
# 1          2016          IND          India             South Asia
# 2          2016          ITA          Italy  Europe & Central Asia
# 3          2016          USA  United States          North America
#
# indicator         Income Group    Lending Type  NE.EXP.GNFS.ZS  \
# 0          Upper middle income            IBRD       19.584380
# 1          Lower middle income            IBRD       19.158235
# 2                  High income  Not classified       29.327891
# 3                  High income  Not classified       11.939539
#
# indicator  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               36.894415       39.580622       13483.377267
# 1               40.082486       26.619000        5839.864817
# 2               55.367603       21.217944       39926.954663
# 3               26.586999       18.042221       57866.744934

# %%
fig = px.pie(year_2016,
    names="Country Name",
    values="NV.IND.TOTL.ZS",
    title=" Countries by 2016 Industry (including construction), value added (% of GDP)",
    color='Country Name',
    labels={"Year":"Year","NV.IND.TOTL.ZS":"Industry (including construction), value added<br>(% of GDP)"},

    
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.16.1.min.js"></script>                <div id="94767ea2-261d-4dde-9347-154f72a448cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94767ea2-261d-4dde-9347-154f72a448cf")) {                    Plotly.newPlot(                        "94767ea2-261d-4dde-9347-154f72a448cf",                        [{"customdata":[["China"],["India"],["Italy"],["United States"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country Name=%{customdata[0]}<br>Industry (including construction), value added<br>(% of GDP)=%{value}<extra></extra>","labels":["China","India","Italy","United States"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa"]},"name":"","showlegend":true,"values":[39.5806215023,26.61899994,21.2179443784,18.0422212818],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar ...

# %% [markdown]
# ## GDP per capita, PPP (current international $):
# - The gross domestic product (GDP) is a metric that measures the economic output of a country. The number of goods and services produced in a country with a higher GDP will be greater.
# - The United States has the highest GDP of 68.4%, while India has the lowest GDP of 8 percent, as shown in the chart above. Despite minimal contributions from exports and trade to the United States, science and technology have contributed to the country's higher GDP than other countries.

# %%
df_pivot2 = df2.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot2.head()
# Out:
# indicator  Year Country Code   Country Name                 Region  \
# 0          2016          CHN          China    East Asia & Pacific
# 1          2016          IND          India             South Asia
# 2          2016          ITA          Italy  Europe & Central Asia
# 3          2016          USA  United States          North America
# 4          2017          CHN          China    East Asia & Pacific
#
# indicator         Income Group    Lending Type  NE.EXP.GNFS.ZS  \
# 0          Upper middle income            IBRD       19.584380
# 1          Lower middle income            IBRD       19.158235
# 2                  High income  Not classified       29.327891
# 3                  High income  Not classified       11.939539
# 4          Upper middle income            IBRD       19.692277
#
# indicator  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               36.894415       39.580622       13483.377267
# 1               40.082486       26.619000        5839.864817
# 2               55.367603       21.217944       39926.954663
# 3               26.586999       18.042221       57866.744934
# 4               37.632413       39.851698       14243.532611

# %%
fig = px.line(df_pivot2,
    x="Year",
    y="NY.GDP.PCAP.PP.CD",
    title=" Countries by 2020 Trade(% of GDP)",
    color='Country Name',
    labels={"Year":"Year","NV.IND.TOTL.ZS":"Industry (including construction), value added<br>(% of GDP)"},
    hover_name='Country Name',
    
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.16.1.min.js"></script>                <div id="d232ead4-e9ed-450a-b286-a47e3dbe1c48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d232ead4-e9ed-450a-b286-a47e3dbe1c48")) {                    Plotly.newPlot(                        "d232ead4-e9ed-450a-b286-a47e3dbe1c48",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=China<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["China","China","China","China","China","China"],"legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[13483.3772665319,14243.5326108491,15495.5484221015,16652.0988008531,17189.281794248,19338.234084501],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["India","India","India","India","India","India"],"legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[5839.8648167534,6182.9221085744,6669.6227843001,6971.6872764783,6525.4280520948,7333.505611842],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=Italy<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["Italy","Italy","Italy","Italy","Italy","Italy"],"legendgroup":"Italy","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Italy","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[39926.9546628592,41581.120790548,43036.2437770367,44376.1625028912,41987.8159630472,45935.9965539678],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=United States<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["United States","United States","United States","United States","United States","United States"],"legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[57866.7449341091,59914.7777969757,62805.2537579917,65094.7994287929,63027.6795267153,69287.536587952],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl" ...

# %% [markdown]
# # Industrialisation vs Exports Of Goods among different Years:

# %%
fig = px.scatter(
    df_pivot2,
    x="NV.IND.TOTL.ZS",
    y="	NE.EXP.GNFS.ZS", 
    title="Wealth vs Health", 
    color="Country Name", 
    
) 

fig.update_layout(showlegend=True)
fig.update_layout(
    xaxis_title="Industrialisation",
    yaxis_title="Exports Of Goods",)


fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-516144d007f4> in <module>
#       4     y=" NE.EXP.GNFS.ZS",
#       5     title="Wealth vs Health",
# ----> 6     color="Country Name",
#       7
#       8 )
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#      67
#      68
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1988     apply_default_cascade(args)
#    1989
# -> 1990     args = build_dataframe(args, constructor)
#    1991     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992         args = process_dataframe_hierarchy(args)
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1404
#    1405     df_output, wide_id_vars = process_args_into_dataframe(
# -> 1406         args, wide_mode, var_name, value_name
#    1407     )
#    1408
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205                         if argument == "index":
#    1206                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207                         raise ValueError(err_msg)
#    1208                 elif length and len(df_input[argument]) != length:
#    1209                     raise ValueError(
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['Year', 'Country Code', 'Country Name', 'Region', 'Income Group', 'Lending Type', 'NE.EXP.GNFS.ZS', 'NE.TRD.GNFS.ZS', 'NV.IND.TOTL.ZS', 'NY.GDP.PCAP.PP.CD'] but received: 	NE.EXP.GNFS.ZS

# %% [markdown]
# ### **Conclusion**
# - We learned how exports of goods and services, industry, and trade contribute to the economic growth of the respective countries from the above information. We also compared the GDP per capita of four other countries.
