# %% [markdown]
# ## NAME- MANISH BHIMA
#
# # Factors that influence the economy and growth of a country
#
# ## INDICATORS:
# - Exports of goods and services (% of GDP)
#
# - Trade (% of GDP)
#
# - Industry (including construction), value added (% of GDP)
#
# - GDP per capita, PPP (current international $)
#
# ## Countries compared:
# - India
#
# - United states
#
# - Italy
#
# - China
# ## Introduction:
# - Economic growth is defined as a rise or improvement in the market value of an economy's commodities and services through time. This expansion is likewise proportional to the percent rate of rise in real Gross Domestic Product (GDP).

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("https://raw.githubusercontent.com/manishbhima/Data690_DVS/main/world_development_explorer/wdx_long%20(1).csv",index_col=0)
df.head(2)
# Out:
#    Year      value       indicator Country Code Country Name  \
# 0  2016  19.584380  NE.EXP.GNFS.ZS          CHN        China
# 1  2017  19.692277  NE.EXP.GNFS.ZS          CHN        China
#
#                 Region         Income Group Lending Type
# 0  East Asia & Pacific  Upper middle income         IBRD
# 1  East Asia & Pacific  Upper middle income         IBRD

# %%
df_2016 = df.query("Year == 2016")
df_2016.sample(5)
# Out:
#     Year      value       indicator Country Code   Country Name  \
# 6   2016  19.158235  NE.EXP.GNFS.ZS          IND          India
# 58  2016  55.367603  NE.TRD.GNFS.ZS          ITA          Italy
# 41  2016  18.042221  NV.IND.TOTL.ZS          USA  United States
# 52  2016  40.082486  NE.TRD.GNFS.ZS          IND          India
# 35  2016  21.217944  NV.IND.TOTL.ZS          ITA          Italy
#
#                    Region         Income Group    Lending Type
# 6              South Asia  Lower middle income            IBRD
# 58  Europe & Central Asia          High income  Not classified
# 41          North America          High income  Not classified
# 52             South Asia  Lower middle income            IBRD
# 35  Europe & Central Asia          High income  Not classified

# %%
df_2016 = df_2016.query("indicator in['NE.EXP.GNFS.ZS','NE.TRD.GNFS.ZS','NV.IND.TOTL.ZS','NY.GDP.PCAP.PP.CD']")
df_2016.head()
# Out:
#     Year      value       indicator Country Code   Country Name  \
# 0   2016  19.584380  NE.EXP.GNFS.ZS          CHN          China
# 6   2016  19.158235  NE.EXP.GNFS.ZS          IND          India
# 12  2016  29.327891  NE.EXP.GNFS.ZS          ITA          Italy
# 18  2016  11.939539  NE.EXP.GNFS.ZS          USA  United States
# 23  2016  39.580622  NV.IND.TOTL.ZS          CHN          China
#
#                    Region         Income Group    Lending Type
# 0     East Asia & Pacific  Upper middle income            IBRD
# 6              South Asia  Lower middle income            IBRD
# 12  Europe & Central Asia          High income  Not classified
# 18          North America          High income  Not classified
# 23    East Asia & Pacific  Upper middle income            IBRD

# %%
df_pivot = pd.pivot(df_2016,index =['Country Code','Country Name'], columns='indicator', values='value').reset_index()
df_pivot.head()
# Out:
# indicator Country Code   Country Name  NE.EXP.GNFS.ZS  NE.TRD.GNFS.ZS  \
# 0                  CHN          China       19.584380       36.894415
# 1                  IND          India       19.158235       40.082486
# 2                  ITA          Italy       29.327891       55.367603
# 3                  USA  United States       11.939539       26.586999
#
# indicator  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               39.580622       13483.377267
# 1               26.619000        5839.864817
# 2               21.217944       39926.954663
# 3               18.042221       57866.744934

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country Code       4 non-null      object
#  1   Country Name       4 non-null      object
#  2   Region             4 non-null      object
#  3   Income Group       4 non-null      object
#  4   Lending Type       4 non-null      object
#  5   NE.EXP.GNFS.ZS     4 non-null      float64
#  6   NE.TRD.GNFS.ZS     4 non-null      float64
#  7   NV.IND.TOTL.ZS     4 non-null      float64
#  8   NY.GDP.PCAP.PP.CD  4 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 416.0+ bytes

# %%
fig=px.bar(df_pivot,x='Country Name',y='NE.EXP.GNFS.ZS',color="Country Name",title="TOP 5 Countries by 2016 Exports of goods and services (% of GDP)").update_xaxes(categoryorder="total descending")

fig.update_layout(yaxis_title="2016 Exports of goods and services (% of GDP)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cac51164-f708-46f7-88f8-3ec1526021d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cac51164-f708-46f7-88f8-3ec1526021d7")) {                    Plotly.newPlot(                        "cac51164-f708-46f7-88f8-3ec1526021d7",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[19.5843800536],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[19.1582349106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[29.3278907466],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[11.9395387322],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{" ...

# %% [markdown]
# #  Economic growth due to Indsutries:
# -  Export sales growth generates revenue and earnings for firms, allowing them to boost capital expenditure. Higher investment boosts a country's production capacity, which in turn boosts its export potential.
# - In the year 2016, the percentage of exports of goods and services contributing to GDP by various countries is depicted in the bar graph above.
# - The Italy exports of goods and services contribute 36.7 percent to its GDP, making it the country with the highest proportion of GDP contributed by exports.
# - China with 24.5 of the market, followed by India with 23.9 % and United States with 14.9%..

# %%
df2 = df.query("indicator in['NE.EXP.GNFS.ZS','NE.TRD.GNFS.ZS','NV.IND.TOTL.ZS','NY.GDP.PCAP.PP.CD']")
df2.sample(5)
# Out:
#     Year        value          indicator Country Code   Country Name  \
# 52  2016    40.082486     NE.TRD.GNFS.ZS          IND          India
# 75  2016  5839.864817  NY.GDP.PCAP.PP.CD          IND          India
# 24  2017    39.851698     NV.IND.TOTL.ZS          CHN          China
# 61  2019    59.879470     NE.TRD.GNFS.ZS          ITA          Italy
# 17  2021    32.738503     NE.EXP.GNFS.ZS          ITA          Italy
# 68  2020    23.442457     NE.TRD.GNFS.ZS          USA  United States
# 10  2020    18.708899     NE.EXP.GNFS.ZS          IND          India
# 7   2017    18.791765     NE.EXP.GNFS.ZS          IND          India
# 59  2017    58.604176     NE.TRD.GNFS.ZS          ITA          Italy
# 5   2021    20.009814     NE.EXP.GNFS.ZS          CHN          China
#
#                    Region         Income Group    Lending Type
# 52             South Asia  Lower middle income            IBRD
# 75             South Asia  Lower middle income            IBRD
# 24    East Asia & Pacific  Upper middle income            IBRD
# 61  Europe & Central Asia          High income  Not classified
# 17  Europe & Central Asia          High income  Not classified
# 68          North America          High income  Not classified
# 10             South Asia  Lower middle income            IBRD
# 7              South Asia  Lower middle income            IBRD
# 59  Europe & Central Asia          High income  Not classified
# 5     East Asia & Pacific  Upper middle income            IBRD

# %%
df_pivot2 = df2.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot2.head()


year_2016=df_pivot2[df_pivot2["Year"]==2016]

# %%
year_2016=df_pivot2[df_pivot2["Year"]==2016]

# %%
year_2016
# Out:
# indicator  Year Country Code   Country Name                 Region  \
# 0          2016          CHN          China    East Asia & Pacific
# 1          2016          IND          India             South Asia
# 2          2016          ITA          Italy  Europe & Central Asia
# 3          2016          USA  United States          North America
#
# indicator         Income Group    Lending Type  NE.EXP.GNFS.ZS  \
# 0          Upper middle income            IBRD       19.584380
# 1          Lower middle income            IBRD       19.158235
# 2                  High income  Not classified       29.327891
# 3                  High income  Not classified       11.939539
#
# indicator  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               36.894415       39.580622       13483.377267
# 1               40.082486       26.619000        5839.864817
# 2               55.367603       21.217944       39926.954663
# 3               26.586999       18.042221       57866.744934

# %%
fig = px.pie(year_2016,
    names="Country Name",
    values="NV.IND.TOTL.ZS",
    title=" Countries by 2016 Industry (including construction), value added (% of GDP)",
    color='Country Name',
    labels={"Year":"Year","NV.IND.TOTL.ZS":"Industry (including construction), value added<br>(% of GDP)"},
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="25aea47c-f9ab-40b8-babe-637fc067091a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25aea47c-f9ab-40b8-babe-637fc067091a")) {                    Plotly.newPlot(                        "25aea47c-f9ab-40b8-babe-637fc067091a",                        [{"customdata":[["China"],["India"],["Italy"],["United States"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country Name=%{customdata[0]}<br>Industry (including construction), value added<br>(% of GDP)=%{value}<extra></extra>","labels":["China","India","Italy","United States"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa"]},"name":"","showlegend":true,"values":[39.5806215023,26.61899994,21.2179443784,18.0422212818],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true, ...

# %% [markdown]
# ## GDP per capita, PPP (current international $):
# - The gross domestic product (GDP) is a metric that measures the economic output of a country. The number of goods and services produced in a country with a higher GDP will be greater.
# - The United States has the highest GDP of 68.4%, while India has the lowest GDP of 8 percent, as shown in the chart above. Despite minimal contributions from exports and trade to the United States, science and technology have contributed to the country's higher GDP than other countries.

# %%
df_pivot2 = df2.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot2.head()
# Out:
# indicator  Year Country Code   Country Name                 Region  \
# 0          2016          CHN          China    East Asia & Pacific
# 1          2016          IND          India             South Asia
# 2          2016          ITA          Italy  Europe & Central Asia
# 3          2016          USA  United States          North America
# 4          2017          CHN          China    East Asia & Pacific
#
# indicator         Income Group    Lending Type  NE.EXP.GNFS.ZS  \
# 0          Upper middle income            IBRD       19.584380
# 1          Lower middle income            IBRD       19.158235
# 2                  High income  Not classified       29.327891
# 3                  High income  Not classified       11.939539
# 4          Upper middle income            IBRD       19.692277
#
# indicator  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               36.894415       39.580622       13483.377267
# 1               40.082486       26.619000        5839.864817
# 2               55.367603       21.217944       39926.954663
# 3               26.586999       18.042221       57866.744934
# 4               37.632413       39.851698       14243.532611

# %%
fig = px.line(df_pivot2,
    x="Year",
    y="NY.GDP.PCAP.PP.CD",
    title=" Countries by 2020 Trade(% of GDP)",
    color='Country Name',
    labels={"Year":"Year","NV.IND.TOTL.ZS":"Industry (including construction), value added<br>(% of GDP)"},
    hover_name='Country Name',
    
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="278fba22-10f5-4ae4-a4b9-c4f2a452c56f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("278fba22-10f5-4ae4-a4b9-c4f2a452c56f")) {                    Plotly.newPlot(                        "278fba22-10f5-4ae4-a4b9-c4f2a452c56f",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=China<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["China","China","China","China","China","China"],"legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[13483.3772665319,14243.5326108491,15495.5484221015,16652.0988008531,17189.281794248,19338.234084501],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["India","India","India","India","India","India"],"legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[5839.8648167534,6182.9221085744,6669.6227843001,6971.6872764783,6525.4280520948,7333.505611842],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=Italy<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["Italy","Italy","Italy","Italy","Italy","Italy"],"legendgroup":"Italy","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Italy","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[39926.9546628592,41581.120790548,43036.2437770367,44376.1625028912,41987.8159630472,45935.9965539678],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=United States<br>Year=%{x}<br>NY.GDP.PCAP.PP.CD=%{y}<extra></extra>","hovertext":["United States","United States","United States","United States","United States","United States"],"legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[57866.7449341091,59914.7777969757,62805.2537579917,65094.7994287929,63027.6795267153,69287.536587952],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111111 ...

# %%
df_pivot2.head(2)
# Out:
# indicator  Year Country Code Country Name               Region  \
# 0          2016          CHN        China  East Asia & Pacific
# 1          2016          IND        India           South Asia
#
# indicator         Income Group Lending Type  NE.EXP.GNFS.ZS  NE.TRD.GNFS.ZS  \
# 0          Upper middle income         IBRD       19.584380       36.894415
# 1          Lower middle income         IBRD       19.158235       40.082486
#
# indicator  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0               39.580622       13483.377267
# 1               26.619000        5839.864817

# %% [markdown]
# # Industrialisation vs Exports Of Goods among different Years:

# %%
fig = px.scatter(
    df_pivot2,
    x="NV.IND.TOTL.ZS",
    y="NE.EXP.GNFS.ZS", 
    title="Wealth vs Health", 
    color="Country Name", 
) 

fig.update_layout(showlegend=True)
fig.update_layout(
    xaxis_title="Industrialisation",
    yaxis_title="Exports Of Goods",)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9ba3383f-49ab-494b-ac79-9bf89c9687a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ba3383f-49ab-494b-ac79-9bf89c9687a5")) {                    Plotly.newPlot(                        "9ba3383f-49ab-494b-ac79-9bf89c9687a5",                        [{"hovertemplate":"Country Name=China<br>NV.IND.TOTL.ZS=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"China","orientation":"v","showlegend":true,"x":[39.5806215023,39.8516984492,39.6870118234,38.5874054561,37.84278691,39.4260685581],"xaxis":"x","y":[19.5843800536,19.6922769882,19.1121035364,18.4099923155,18.5410600111,20.0098140678],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=India<br>NV.IND.TOTL.ZS=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"India","orientation":"v","showlegend":true,"x":[26.61899994,26.5000166467,26.4120919017,24.5964578829,24.5310661886,25.8718010169],"xaxis":"x","y":[19.1582349106,18.7917648393,19.9278285989,18.6909827074,18.7088986866,20.8136349598],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Italy<br>NV.IND.TOTL.ZS=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Italy","orientation":"v","showlegend":true,"x":[21.2179443784,21.300405023,21.4501517226,21.5271247819,21.6067526526,22.5776378134],"xaxis":"x","y":[29.3278907466,30.7337333196,31.3535542008,31.6026782976,29.5325109401,32.738503052],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=United States<br>NV.IND.TOTL.ZS=%{x}<br>NE.EXP.GNFS.ZS=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"United States","orientation":"v","showlegend":true,"x":[18.0422212818,18.4366014618,18.6167766258,18.295603047,18.4387545564,null],"xaxis":"x","y":[11.9395387322,12.2371893966,12.3422406728,11.7895354311,10.1628986024,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscal ...
